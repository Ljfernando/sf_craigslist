# %%
import pandas as pd
import json
import numpy as np

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           1  $895 / 1br - 500ft2 - 1 BD + 1 BD WATER PAID$ ...
# 1           2  $895 / 1br - 500ft2 - 1 BD + 1 BD WATER PAID$ ...
# 2           3  $895 / 1br - 500ft2 - 1 BD + 1 BD WATER PAID$ ...
# 3           4  $895 / 1br - 500ft2 - 1 BD + 1 BD WATER PAID$ ...
# 4           5  $895 / 1br - 500ft2 - 1 BD + 1 BD WATER PAID$ ...
#
#                                                 text   latitude   longitude  \
# 0  QR Code Link to This Post\n            \n     ...  34.860788 -118.170104
# 1  QR Code Link to This Post\n            \n     ...  34.861017 -118.169932
# 2  QR Code Link to This Post\n            \n     ...  34.861017 -118.169932
# 3  QR Code Link to This Post\n            \n     ...  34.861017 -118.169932
# 4  QR Code Link to This Post\n            \n     ...  34.860683 -118.169997
#
#                    city_text          date_posted         date_updated  price  \
# 0  W. ROSAMOND BLVD. / B ST.  2018-10-08 22:29:36  2018-10-15 13:07:37  895.0
# 1  W. ROSAMOND BLVD. / B ST.  2018-10-15 11:44:23                  NaN  895.0
# 2  W. ROSAMOND BLVD. / B ST.  2018-10-15 11:53:06                  NaN  895.0
# 3  W. ROSAMOND BLVD. / B ST.  2018-10-15 13:30:43                  NaN  895.0
# 4  W. ROSAMOND BLVD. / B ST.  2018-10-15 13:36:07                  NaN  895.0
#
#    deleted  ...    bedrooms  bathrooms  pets laundry     parking  craigslist  \
# 0    False  ...         1.0        1.0  none  shared  off-street  losangeles
# 1    False  ...         1.0        1.0  none  shared  off-street  losangeles
# 2    False  ...         1.0        1.0  none  shared  off-street  losangeles
# 3    False  ...         1.0        1.0  none  shared  off-street  losangeles
# 4    False  ...         1.0        1.0  none  shared  off-street  losangeles
#
#       place city state county
# 0  Rosamond  NaN    CA   Kern
# 1  Rosamond  NaN    CA   Kern
# 2  Rosamond  NaN    CA   Kern
# 3  Rosamond  NaN    CA   Kern
# 4  Rosamond  NaN    CA   Kern
#
# [5 rows x 21 columns]

# %%
df[df.county=='San Francisco'].describe()
# Out:
#          Unnamed: 0     latitude    longitude         price         sqft  \
# count   2894.000000  2894.000000  2894.000000   2891.000000  1160.000000
# mean   20421.670352    37.776703  -122.428186   3675.764095   914.092241
# std     1086.295202     0.019805     0.025506   1605.044289   490.289148
# min     3533.000000    37.708232  -122.510248      0.000000     1.000000
# 25%    19720.250000    37.768996  -122.440511   2624.000000   623.750000
# 50%    20458.500000    37.781300  -122.422879   3459.000000   805.000000
# 75%    21203.500000    37.790434  -122.413011   4390.000000  1102.000000
# max    21948.000000    37.823100  -122.368684  17700.000000  8933.000000
#
#           bedrooms    bathrooms
# count  2721.000000  2721.000000
# mean      1.319735     1.214627
# std       0.979914     0.506087
# min       0.000000     0.000000
# 25%       1.000000     1.000000
# 50%       1.000000     1.000000
# 75%       2.000000     1.000000
# max       6.000000     5.000000

# %%
sf = df[df.county=='San Francisco']
sf.shape
# Out:
# (2894, 21)

# %%
sf['title'] = [title.split('\n')[0] for title in sf.title.values]
sf = sf.loc[sf.title.str.contains('\(')]
sf['neighborhood'] = [nh.split('(')[1][:-1] for nh in sf.title.values]
sf['title'] = [nh.split('(')[0] for nh in sf.title.values]
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
valid_neighborhoods = sf.neighborhood.value_counts()[sf.neighborhood.value_counts() > 4].index
valid_n = np.asarray([curr in valid_neighborhoods for curr in sf.neighborhood.values])
sf = sf.loc[valid_n]

# %%
sf['price_bucket'] = pd.qcut(sf.price, 4)

# %%
sf.shape
# Out:
# (2689, 22)

# %%
sf.to_csv('sf.csv', index=False)

# %%
sf.head(10).T
# Out:
#                                                           3532   \
# Unnamed: 0                                                 3533
# title         $2000 Are you looking for an AFFORDABLE home? ...
# text          QR Code Link to This Post\n            \n     ...
# latitude                                                37.7749
# longitude                                              -122.419
# city_text                                                   NaN
# date_posted                                 2018-10-01 09:34:37
# date_updated                                2018-10-14 11:26:18
# price                                                      2000
# deleted                                                   False
# sqft                                                        NaN
# bedrooms                                                    NaN
# bathrooms                                                   NaN
# pets                                                       none
# laundry                                                    none
# parking                                                    none
# craigslist                                           sacramento
# place                                             San Francisco
# city                                              San Francisco
# state                                                        CA
# county                                            San Francisco
#
#                                                           4554   \
# Unnamed: 0                                                 4555
# title         $5241 / 2br - 1095ft2 - Large Two Bedroom In G...
# text          QR Code Link to This Post\n            \n     ...
# latitude                                                37.7878
# longitude                                              -122.393
# city_text                 333 Fremont Street, San Francisco CA.
# date_posted                                 2018-10-06 16:25:41
# date_updated                                2018-10-12 17:54:03
# price                                                      5241
# deleted                                                   False
# sqft                                                       1095
# bedrooms                                                      2
# bathrooms                                                     2
# pets                                                       both
# laundry                                                 in-unit
# parking                                                  garage
# craigslist                                           sacramento
# place                                             San Francisco
# city                                              San Francisco
# state                                                        CA
# county                                            San Francisco
#
#                                                           9389   \
# Unnamed: 0                                                 9390
# title         $7950 / 3br - 2030ft2 - 3 beds 3 baths Spaciou...
# text          QR Code Link to This Post\n            \n     ...
# latitude                                                37.7621
# longitude                                              -122.397
# city_text                                          Potrero Hill
# date_posted                                 2018-10-12 09:19:33
# date_updated                                2018-10-15 08:18:26
# price                                                      7950
# deleted                                                   False
# sqft                                                       2030
# bedrooms                                                      3
# bathrooms                                                     3
# pets                                                       none
# laundry                                                     NaN
# parking                                                  garage
# craigslist                                            sfbay_eby
# place                                             San Francisco
# city                                              San Francisco
# state                                                        CA
# county                                            San Francisco
#
#                                                           10433  \
# Unnamed: 0                                                10434
# title         $1495 / 300ft2 - Happy and Restful Studio in S...
# text          QR Code Link to This Post\n            \n     ...
# latitude                                                 37.738
# longitude                                              -122.409
# city_text                                          oakland west
# date_posted                                 2018-09-28 06:39:14
# date_updated                                2018-10-13 05:06:21
# price                                                      1495
# deleted                                                   False
# sqft                                                        300
# bedrooms                                                      0
# bathrooms                                                     1
# pets                                                       both
# laundry                                                  shared
# parking                                                    none
# craigslist                                            sfbay_eby
# place                                             San Francisco
# city                                              San Francisco
# state                                                        CA
# county                                            San Francisco
#
#                                                           10884  \
# Unnamed: 0                                                10885
# title         $1400 Newly renovated apt. w/ balcony, granite...
# text          QR Code Link to This Post\n            \n     ...
# latitude                                                37.7812
# longitude                                              -122.461
# city_text                                     /*san francisco*/
# date_posted                                 2018-10-15 12:42:11
# date_updated                                                NaN
# price                                                      1400
# deleted                                                   False
# sqft                                                        NaN
# bedrooms                                                    NaN
# bathrooms                                                   NaN
# pets                                                       none
# laundry                                                 in-unit
# parking                                                    none
# craigslist                                            sfbay_eby
# place                                             San Francisco
# city                                              San Francisco
# state                                                        CA
# county                                            San Francisco
#
#                                                           11494  \
# Unnamed: 0                                                11495
# title         $1645 Studio in Historic Pet-friendly Building...
# text          QR Code Link to This Post\n            \n     ...
# latitude                                                37.7813
# longitude                                              -122.417
# city_text                                  danville / san ramon
# date_posted                                 2018-10-01 14:38:01
# date_updated                                2018-10-15 09:49:21
# price                                                      1645
# deleted                                                   False
# sqft                                                        NaN
# bedrooms                                                      0
# bathrooms                                                     1
# pets                                                       both
# laundry                                                  shared
# parking                                                    none
# craigslist                                            sfbay_eby
# place                                             San Francisco
# city                                              San Francisco
# state                                                        CA
# county                                            San Francisco
#
#                                                           12123  \
# Unnamed: 0                                                12124
# title         $3750 / 2br - 850ft2 - Adorable two bedroom / ...
# text          QR Code Link to This Post\n            \n     ...
# latitude                                                37.7707
# longitude                                              -122.449
# city_text                                   rohnert pk / cotati
# date_posted                                 2018-10-15 13:59:17
# date_updated                                                NaN
# price                                                      3750
# deleted                                                   False
# sqft                                                        850
# bedrooms                                                      2
# bathrooms                                                     1
# pets                                                       none
# laundry                                                  shared
# parking                                                    none
# craigslist                                            sfbay_nby
# place                                             San Francisco
# city                                              San Francisco
# state                                                        CA
# county                                            San Francisco
#
#                                                           12396  \
# Unnamed: 0                                                12397
# title         $3750 / 2br - Bright 2 bedroom unit ~ Newly re...
# text          QR Code Link to This Post\n            \n     ...
# latitude                                                37.7707
# longitude                                              -122.449
# city_text                                   rohnert pk / cotati
# date_posted                                 2018-10-09 13:49:06
# date_updated                                                NaN
# price                                                      3750
# deleted                                                   False
# sqft                                                        NaN
# bedrooms                                                      2
# bathrooms                                                     1
# pets                                                       none
# laundry                                                  shared
# parking                                                    none
# craigslist                                            sfbay_nby
# place                                             San Francisco
# city                                              San Francisco
# state                                                        CA
# county                                            San Francisco
#
#                                                           12472  \
# Unnamed: 0                                                12473
# title         $3750 / 2br - 850ft2 - Completely remodeled 2 ...
# text          QR Code Link to This Post\n            \n     ...
# latitude                                                37.7707
# longitude                                              -122.449
# city_text                                   rohnert pk / cotati
# date_posted                                 2018-10-11 18:36:56
# date_updated                                                NaN
# price                                                      3750
# deleted                                                   False
# sqft                                                        850
# bedrooms                                                      2
# bathrooms                                                     1
# pets                                                       none
# laundry                                                  shared
# parking                                                    none
# craigslist                                            sfbay_nby
# place                                             San Francisco
# city                                              San Francisco
# state                                                        CA
# county                                            San Francisco
#
#                                                           12809
# Unnamed: 0                                                12810
# title         $3750 / 2br - 850ft2 - Incredible 2 bedroom - ...
# text          QR Code Link to This Post\n            \n     ...
# latitude                                                37.7707
# longitude                                              -122.449
# city_text                                   rohnert pk / cotati
# date_posted                                 2018-10-08 10:11:32
# date_updated                                                NaN
# price                                                      3750
# deleted                                                   False
# sqft                                                        850
# bedrooms                                                      2
# bathrooms                                                     1
# pets                                                       none
# laundry                                                  shared
# parking                                                    none
# craigslist                                            sfbay_nby
# place                                             San Francisco
# city                                              San Francisco
# state                                                        CA
# county                                            San Francisco

# %%
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.
